# %% [markdown]
# <a href="https://colab.research.google.com/github/h7ty56/Statistics/blob/main/Basics_of_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT QUESTIONS

# %%
## QUES 1) Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
## nominal, ordinal, interval, and ratio scales.

# %% [markdown]
# Types of Data in Statistics
# Data can be broadly classified into Qualitative (Categorical) and Quantitative (Numerical) data:
#
#  1. Qualitative (Categorical) Data
# Describes qualities or characteristics that cannot be measured numerically.
#
# Divided into Nominal and Ordinal scales.
#
#  a. Nominal Scale
# Characteristics: Categories with no natural order or ranking.
#
# Examples:
#
# Gender: Male, Female, Other
#
# Eye Color: Blue, Brown, Green
#
# Blood Type: A, B, AB, O
#
#  b. Ordinal Scale
# Characteristics: Categories that can be ranked or ordered, but the intervals between ranks are not equal or meaningful.
#
# Examples:
#
# Satisfaction Levels: Poor, Fair, Good, Excellent
#
# Education Levels: High School, Bachelor’s, Master’s, PhD
#
# Military Ranks: Private, Sergeant, Captain, General
#
#  2. Quantitative (Numerical) Data
# Represents numerical values and can be measured.
#
# Divided into Interval and Ratio scales.
#
#  a. Interval Scale
# Characteristics:
#
# Numerical data with equal intervals between values.
#
# No true zero point (zero doesn't indicate absence of the property).
#
# Examples:
#
# Temperature in Celsius or Fahrenheit (0°C is not the absence of temperature).
#
# IQ Scores.
#
# Calendar Years (e.g., 2000, 2020).
#
#  b. Ratio Scale
# Characteristics:
#
# Numerical data with equal intervals and a true zero point (zero indicates the absence of the property).
#
# Permits all mathematical operations (addition, subtraction, multiplication, division).
#
# Examples:
#
# Height (cm, inches).
#
# Weight (kg, lbs).
#
# Age (years).
#
# Income (dollars).

# %%
## QUES 2) What are the measures of central tendency, and when should you use each? Discuss the mean, median,
## and mode with examples and situations where each is appropriate.

# %% [markdown]
# Measures of Central Tendency
#
# Measures of central tendency are statistics that describe the center or typical value of a dataset. The three main measures are:
#
# Mean (Average)
#
# Median (Middle Value)
#
# Mode (Most Frequent Value)
#
#  1. Mean (Average)
#  Definition:
# The mean is the sum of all data points divided by the number of points. It is suitable for quantitative data.
#
#  Formula:
# Mean
# =
# ∑
# 𝑋
# 𝑖
# 𝑛
# Mean=
# n
# ∑X
# i
# ​
#
# ​
#
# Where:
#
# 𝑋
# 𝑖
# X
# i
# ​
#   = Each individual data point
#
# 𝑛
# n = Total number of data points
#
#  Example:
# Dataset:
# 4
# ,
# 8
# ,
# 6
# ,
# 5
# ,
# 3
# ,
# 8
# ,
# 10
# 4,8,6,5,3,8,10
#
# Mean
# =
# 4
# +
# 8
# +
# 6
# +
# 5
# +
# 3
# +
# 8
# +
# 10
# 7
# =
# 44
# 7
# ≈
# 6.29
# Mean=
# 7
# 4+8+6+5+3+8+10
# ​
#  =
# 7
# 44
# ​
#  ≈6.29
#  When to Use:
# When the data is symmetrically distributed.
#
# When you want to include all data points in the calculation.
#
# Appropriate for interval and ratio data.
#
#  When NOT to Use:
# When the dataset contains outliers (e.g., income distribution).
#
#  2. Median (Middle Value)
#  Definition:
# The median is the middle value of a dataset when it is arranged in order. If there is an even number of observations, it is the average of the two middle values.
#
#  Example:
# Dataset:
# 4
# ,
# 8
# ,
# 6
# ,
# 5
# ,
# 3
# ,
# 8
# ,
# 10
# 4,8,6,5,3,8,10 (Sorted:
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# ,
# 8
# ,
# 8
# ,
# 10
# 3,4,5,6,8,8,10)
#
# Median
# =
# 6
# Median=6
# For an even number of elements:
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# 1,2,3,4
#
# Median
# =
# 2
# +
# 3
# 2
# =
# 2.5
# Median=
# 2
# 2+3
# ​
#  =2.5
#  When to Use:
# When the data is skewed or contains outliers.
#
# When dealing with ordinal data (e.g., rankings).
#
#  When NOT to Use:
# When you need to consider every data point in the calculation.
#
#  3. Mode (Most Frequent Value)
# Definition:
#
# The mode is the most frequently occurring value in a dataset. There can be more than one mode if multiple values have the same highest frequency.
#
# Example:
# Dataset:
# 4
# ,
# 8
# ,
# 6
# ,
# 5
# ,
# 3
# ,
# 8
# ,
# 10
# 4,8,6,5,3,8,10
#
# Mode
# =
# 8
# Mode=8
# For a bimodal dataset:
# 1
# ,
# 2
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 4
# ,
# 5
# 1,2,2,3,4,4,5
#
# Modes
# =
# 2
# ,
# 4
# Modes=2,4
#  When to Use:
# For categorical data (e.g., most popular color).
#
# When identifying the most common observation is important.
#
# Works for nominal, ordinal, interval, and ratio data.
#
#  When NOT to Use:
# When all values are unique (no mode).
#
# When you need a single representative value for numerical analysis.

# %%
## QUES 3)  Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?

# %% [markdown]
# Dispersion refers to the extent to which data points in a dataset are spread out or scattered. It helps us understand how much variability exists within the data. A higher dispersion means the data points are more spread out from the center, while a lower dispersion indicates that they are closer to the central value (like the mean or median).
#
# Dispersion is important because:
#
# It provides insight into the consistency or reliability of the data.
#
# Helps identify outliers and data variability.
#
# Complements measures of central tendency (mean, median, mode) by providing additional information about the dataset's distribution.
#
# Measures of Dispersion:
#
# The most common measures of dispersion are:
#
# Range
#
# Interquartile Range (IQR)
#
# Variance
#
# Standard Deviation
#
# Variance :
#
# Definition:
# Variance measures the average squared deviation of each data point from the mean. It quantifies how much the data points differ from the mean in a squared scale.
#
# Formula (Population Variance):
#
# 𝜎
# 2
# =
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑋
# 𝑖
# −
# 𝜇
# )
# 2
# 𝑁
# σ
# 2
#  =
# N
# ∑
# i=1
# N
# ​
#  (X
# i
# ​
#  −μ)
# 2
#
# ​
#
#  Formula (Sample Variance):
# 𝑠
# 2
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# 𝑛
# −
# 1
# s
# 2
#  =
# n−1
# ∑
# i=1
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )
# 2
#
# ​
#
# Where:
#
# 𝑋
# 𝑖
# X
# i
# ​
#   = Each individual data point
#
# 𝜇
# μ = Population mean
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝑁
# N = Total number of data points (population)
#
# 𝑛
# n = Number of data points (sample)
#
#  Example:
#
# Dataset:
# 4
# ,
# 8
# ,
# 6
# ,
# 5
# ,
# 3
# ,
# 8
# ,
# 10
# 4,8,6,5,3,8,10
# Mean
# 𝑋
# ˉ
# =
# 6.29
# X
# ˉ
#  =6.29
#
# Variance
# =
# (
# 4
# −
# 6.29
# )
# 2
# +
# (
# 8
# −
# 6.29
# )
# 2
# +
# …
# +
# (
# 10
# −
# 6.29
# )
# 2
# 7
# −
# 1
# ≈
# 6.19
# Variance=
# 7−1
# (4−6.29)
# 2
#  +(8−6.29)
# 2
#  +…+(10−6.29)
# 2
#
# ​
#  ≈6.19
#
#  Standard Deviation:
#
#  Definition:
#
# The standard deviation is the square root of the variance. It measures the average distance of data points from the mean and has the same unit as the original data, making it more interpretable.
#
# Formula:
# 𝜎
# =
# 𝜎
# 2
# (Population)
# σ=
# σ
# 2
#
# ​
#  (Population)
# 𝑠
# =
# 𝑠
# 2
# (Sample)
# s=
# s
# 2
#
# ​
#  (Sample)
# Example:
#
# Standard Deviation
# =
# 6.19
# ≈
# 2.49
# Standard Deviation=
# 6.19
# ​
#  ≈2.49
#  Variance and Standard Deviation Measure Spread in following way:
#
# Variance:
#
# Gives a numerical value representing how data points differ from the mean.
#
# Larger variance = Greater dispersion.
#
# Smaller variance = Data points are closer to the mean.
#
# Standard Deviation:
#
# Represents the average distance of each data point from the mean.
#
# Useful when comparing datasets with the same units.

# %%
## QUES 4)What is a box plot, and what can it tell you about the distribution of data?

# %% [markdown]
# Box Plot (Box-and-Whisker Plot)
#
# A box plot is a graphical representation of the distribution of a dataset that shows the minimum, maximum, median, first quartile (Q1), and third quartile (Q3). It is particularly useful for identifying outliers, skewness, and overall spread of the data.
#
# Key Components of a Box Plot:
#
# Median (Q2):
#
# The middle value of the dataset (50th percentile).
#
# Shown as a line inside the box.
#
# First Quartile (Q1):
#
# The median of the lower half of the dataset (25th percentile).
#
# Represents the boundary of the lower edge of the box.
#
# Third Quartile (Q3):
#
# The median of the upper half of the dataset (75th percentile).
#
# Represents the boundary of the upper edge of the box.
#
# Interquartile Range (IQR):
#
# The range between Q1 and Q3:
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
#
# Represents the middle 50% of the data.
#
# Whiskers:
#
# Extend from Q1 to the minimum value (that is not an outlier) and from Q3 to the maximum value (that is not an outlier).
#
# Whiskers often cover data points within
# 1.5
# ×
# IQR
# 1.5×IQR from Q1 and Q3.
#
# Outliers:
#
# Data points that lie beyond
# 1.5
# ×
# IQR
# 1.5×IQR from Q1 or Q3.
#
# Plotted as individual dots or small circles.
#
#  A Box Plot Tells us About:
#
# Central Tendency (Median):
#
# The line inside the box shows the median, giving insight into the dataset's central value.
#
# Spread (IQR):
#
# The width of the box indicates the spread of the middle 50% of the data.
#
# A wider box = More variability; Narrower box = Less variability.
#
# Skewness:
#
# If the median is closer to Q1 than Q3, the data is right-skewed.
#
# If the median is closer to Q3 than Q1, the data is left-skewed.
#
# If the median is centered, the data is symmetrical.
#
# Outliers:
#
# Points plotted outside the whiskers are potential outliers.
#
# They indicate unusual or extreme values.
#
# Range:
#
# The distance between the whiskers indicates the overall spread of the data.
#
# Example of Box Plot Interpretation
#
# Suppose you have a box plot representing the test scores of students:
#
# Median: 75
#
# Q1: 65, Q3: 85
#
# Minimum (non-outlier): 50
#
# Maximum (non-outlier): 95
#
# Outliers: 30, 100
#
# Interpretation:
#
# The median score is 75.
#
# The middle 50% of scores (IQR) ranges from 65 to 85.
#
# The spread of scores is moderate.
#
# The outliers at 30 and 100 indicate some unusual test scores.
#
# The data is slightly right-skewed, as the median is closer to Q1.

# %%
## QUES 5) Discuss the role of random sampling in making inferences about populations.

# %% [markdown]
# The Role of Random Sampling in Making Inferences About Populations
# Random sampling is a fundamental statistical technique used to draw conclusions about an entire population based on a subset (sample) of that population. It ensures that every member of the population has an equal chance of being selected, making the sample representative and unbiased.
#
# Random Sampling is Important because:
#
# Accuracy of Inferences:
#
# A well-chosen random sample provides reliable estimates of population parameters (e.g., mean, proportion, variance).
#
# It allows researchers to make valid inferences without surveying the entire population.
#
# Avoiding Bias:
#
# Non-random sampling can introduce selection bias, which skews results and makes them untrustworthy.
#
# Random sampling minimizes the risk of bias, making conclusions more generalizable.
#
# Cost and Time Efficiency:
#
# Studying an entire population is often impractical or impossible.
#
# Random sampling allows researchers to gather insights quickly and at a lower cost.
#
# Basis for Statistical Methods:
#
# Random sampling is essential for applying probability theory and conducting hypothesis testing.
#
# Many statistical formulas and models assume random sampling for their validity.
#
# Types of Random Sampling
#
# Simple Random Sampling:
#
# Every member of the population has an equal probability of being selected.
#
# Commonly achieved through random number generators or lottery methods.
#
# Stratified Sampling:
#
# The population is divided into subgroups (strata) based on certain characteristics (e.g., age, gender).
#
# Random samples are drawn from each stratum to ensure representation.
#
# Systematic Sampling:
#
# Selecting every
# 𝑘
# k-th individual from a list or sequence.
#
# Easier to implement but may introduce bias if the list has a pattern.
#
# Cluster Sampling:
#
# Dividing the population into groups (clusters) and randomly selecting entire clusters.
#
# Useful when the population is geographically spread out.
#
#  Making Inferences with Random Sampling
# Estimating Population Parameters:
#
# Example: Estimating the average height of students in a school by sampling a random subset.
#
# Sample statistics (mean, variance) serve as estimates of population parameters.
#
# Hypothesis Testing:
#
# Random samples are used to test null and alternative hypotheses about population characteristics.
#
# Example: Testing if a new drug is effective by comparing randomly selected patients.
#
# Confidence Intervals:
#
# A random sample allows the calculation of confidence intervals to estimate population parameters with a certain level of certainty.
#
# Example: Estimating the proportion of voters favoring a candidate within a margin of error.
#
# Generalizing Results:
#
# If the sample is truly random, findings can be generalized to the entire population.
#
# Non-random samples limit the validity of generalizations.
#
#  Example: Using Random Sampling to Estimate Population Mean
# Imagine you want to estimate the average weight of apples in an orchard.
#
# Population: All apples in the orchard.
#
# Random Sample: 100 apples randomly selected.
#
# Sample Mean Weight: 150 grams.
#
# Confidence Interval: With 95% confidence, the mean weight of all apples is estimated to be between 145 and 155 grams.
#
# Without random sampling, the estimate could be biased if only apples from certain trees or areas are selected.
#
#  Limitations of Random Sampling
#
# Sampling Error:
#
# There is always a possibility of error due to the randomness of the sample. Larger samples reduce this error.
#
# Non-Response Bias:
#
# If certain individuals refuse to participate, it may affect the results.
#
# Practicality Issues:
#
# Achieving a truly random sample is challenging in practice due to accessibility, cost, or logistical issues.

# %%
## QUES 6)  Explain the concept of skewness and its types. How does skewness affect the interpretation of data?

# %% [markdown]
# Skewness is a measure of the asymmetry of a probability distribution or dataset. It indicates whether the data points are symmetrically distributed around the mean or if they tend to concentrate more heavily on one side.
#
# Types of Skewness
#
# Symmetrical Distribution (Zero Skewness):
#
# The left and right sides of the distribution are mirror images of each other.
#
# Mean = Median = Mode.
#
# Example: Ideal normal distribution.
#
# Positive Skewness (Right-Skewed):
#
# The tail on the right side (higher values) is longer or fatter than the left side.
#
# Mean > Median > Mode.
#
# The majority of data points are concentrated on the left with a few large values on the right.
#
# Example: Income distribution in most countries (a few high earners skew the average upward).
#
# Negative Skewness (Left-Skewed):
#
# The tail on the left side (lower values) is longer or fatter than the right side.
#
# Mean < Median < Mode.
#
# The majority of data points are concentrated on the right with a few small values on the left.
#
# Example: Test scores where most students perform well, but a few score poorly.
# Skewness can be quantified using the following formula:
#
# Skewness
# =
# 𝑛
# (
# 𝑛
# −
# 1
# )
# (
# 𝑛
# −
# 2
# )
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# 𝑠
# )
# 3
# Skewness=
# (n−1)(n−2)
# n
# ​
#
# i=1
# ∑
# n
# ​
#  (
# s
# X
# i
# ​
#  −
# X
# ˉ
#
# ​
#  )
# 3
#
# Where:
#
# 𝑛
# n = Number of data points
#
# 𝑋
# 𝑖
# X
# i
# ​
#   = Individual data point
#
# 𝑋
# ˉ
# X
# ˉ
#   = Mean of the data
#
# 𝑠
# s = Standard deviation
#
# A simpler way to measure skewness in Python is using the scipy.stats.skew() function.
#
#  Interpretation of Skewness Value
#
# Skewness = 0: Perfectly symmetrical distribution.
#
# Skewness > 0: Positively skewed (right-skewed).
#
# Skewness < 0: Negatively skewed (left-skewed).
#
# Magnitude: Higher absolute values indicate greater skewness.
#
#  Effects of Skewness on Data Interpretation
#
# Impact on Measures of Central Tendency:
#
# In skewed distributions, the mean is more affected by extreme values than the median.
#
# Example: In a right-skewed distribution, the mean is greater than the median.
#
# Choice of Central Tendency Measure:
#
# Symmetrical Data: Mean is a good measure of central tendency.
#
# Skewed Data: Median is preferred as it is less affected by outliers.
#
# Impact on Statistical Analysis:
#
# Many statistical methods (e.g., regression, t-tests) assume normality (no skewness).
#
# When skewness is present, transformations (e.g., log, square root) may be applied to normalize data.
#
# Outlier Detection:
#
# Significant skewness often indicates the presence of outliers.
#
# Right-skewed: Possible outliers are high-value data points.
#
# Left-skewed: Possible outliers are low-value data points.

# %%
## QUES 7)  What is the interquartile range (IQR), and how is it used to detect outliers?

# %% [markdown]
# Interquartile Range (IQR) and Its Use in Outlier Detection
# The Interquartile Range (IQR) is a measure of statistical dispersion that describes the range within which the central 50% of data points lie. It is particularly useful for identifying outliers because it focuses on the middle portion of the data, ignoring extreme values.
#
#  Definition of IQR
#
# The IQR is calculated as the difference between the 75th percentile (Q3) and the 25th percentile (Q1) of a dataset.
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Q1 (First Quartile): The median of the lower half of the dataset (25th percentile).
#
# Q3 (Third Quartile): The median of the upper half of the dataset (75th percentile).
#
# IQR: Represents the spread of the middle 50% of the data.
#
#   IQR Is Useful because:
#
# Unlike the range, IQR is not affected by extreme values (outliers).
#
# Provides a robust measure of variability.
#
# Commonly used in box plots to visualize data spread and detect outliers.
#
#  Detecting Outliers Using IQR
#
# Outliers are data points that fall significantly outside the central portion of a distribution. To detect outliers using IQR:
#
# Calculate IQR:
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Determine Upper and Lower Bounds:
#
# Upper Bound:
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# Q3+1.5×IQR
#
# Lower Bound:
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# Q1−1.5×IQR
#
# Identify Outliers:
#
# Any data point above the upper bound or below the lower bound is considered an outlier.
#
# Extreme Outliers: Sometimes, an even more stringent criterion is used:
#
# Upper Extreme:
# 𝑄
# 3
# +
# 3
# ×
# IQR
# Q3+3×IQR
#
# Lower Extreme:
# 𝑄
# 1
# −
# 3
# ×
# IQR
# Q1−3×IQR

# %%
## QUES 8) Discuss the conditions under which the binomial distribution is used.

# %% [markdown]
# Conditions for Using the Binomial Distribution
# The Binomial Distribution models the number of successes in a fixed number of independent Bernoulli trials, where each trial results in either a success or a failure. It's one of the most common discrete probability distributions.
#
# Conditions for Binomial Distribution:
#
# The Binomial Distribution applies under four specific conditions:
#
# Fixed Number of Trials (n):
#
# The experiment consists of a fixed number of trials, denoted by
# 𝑛
# n.
#
# Example: Flipping a coin 10 times, conducting 20 surveys, rolling a dice 15 times.
#
# Binary Outcomes (Success or Failure):
#
# Each trial results in one of two mutually exclusive outcomes: Success or Failure.
#
# Example: Coin flip (Heads or Tails), Pass or Fail, Yes or No.
#
# Constant Probability of Success (p):
#
# The probability of success,
# 𝑝
# p, remains constant across all trials.
#
# Example: If the probability of rolling a 6 on a fair die is
# 𝑝
# =
# 1
# 6
# p=
# 6
# 1
# ​
#  , it remains the same for each roll.
#
# Independence of Trials:
#
# The outcome of one trial does not affect the outcome of another.
#
# Example: The probability of getting a head on the 3rd flip is unaffected by the results of the previous flips.
#
#  Probability Mass Function (PMF) of Binomial Distribution
# The probability of getting exactly
# 𝑘
# k successes in
# 𝑛
# n independent trials is given by:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# 𝑛
# n = Total number of trials
#
# 𝑘
# k = Number of successful trials
#
# 𝑝
# p = Probability of success in a single trial
#
# 1
# −
# 𝑝
# 1−p = Probability of failure in a single trial
#
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) = Number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials (Combination formula).
#
# Examples of Binomial Distribution:
#
# Coin Tossing:
#
# Toss a fair coin
# 𝑛
# =
# 10
# n=10 times.
#
# Probability of getting heads
# 𝑝
# =
# 0.5
# p=0.5.
#
# Random variable
# 𝑋
# X = Number of heads obtained.
#
# Manufacturing Defects:
#
# Inspecting 100 items, with a defect probability of
# 𝑝
# =
# 0.02
# p=0.02.
#
# 𝑋
# X = Number of defective items.
#
# Multiple-Choice Quiz:
#
# A quiz has 20 questions, with a
# 𝑝
# =
# 0.25
# p=0.25 probability of guessing a question correctly.
#
# 𝑋
# X = Number of correct answers.
#
#  When Not to Use Binomial Distribution:
#
# The binomial distribution is not appropriate when:
#
# Trials Are Not Independent:
#
# Example: Drawing cards without replacement from a deck.
#
# Probability of Success Varies:
#
# Example: Probability of success changes with each trial.
#
# More Than Two Possible Outcomes:
#
# Example: Rolling a die (six outcomes) unless simplified to success/failure (e.g., rolling a 6 vs. not rolling a 6).

# %%
## QUES 9) Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).

# %% [markdown]
# Properties of the Normal Distribution & Empirical Rule (68-95-99.7 Rule)
# The Normal Distribution (also known as the Gaussian distribution) is one of the most important continuous probability distributions in statistics. It describes data that clusters around a mean in a symmetric, bell-shaped curve.
#
#  Properties of the Normal Distribution
#
# Symmetry
#
# The curve is perfectly symmetric about its mean (
# 𝜇
# μ).
#
# The left and right halves of the curve are mirror images.
#
# Mean, Median, and Mode are Equal
#
# They all occur at the center of the distribution.
#
# Mean = Median = Mode =
# 𝜇
# μ.
#
# Bell-Shaped Curve
#
# The curve is smooth and continuous, extending infinitely in both directions.
#
# Tapers off gradually toward the tails but never touches the x-axis.
#
# Unimodal
#
# There is only one peak (the highest point) at the mean
# 𝜇
# μ.
#
# Asymptotic
#
# The tails approach but never touch the x-axis.
#
# This implies there’s always a non-zero probability for extreme values, although it's very small.
#
# Defined by Two Parameters
#
# Mean (
# 𝜇
# μ): Determines the center of the distribution.
#
# Standard Deviation (
# 𝜎
# σ): Determines the spread or width of the distribution. A larger
# 𝜎
# σ means a wider, flatter curve.
#
# Area Under the Curve = 1
#
# The total area under the curve represents a probability of 1 (or 100%).
#
#  Probability Density Function (PDF) of Normal Distribution
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 2
# 𝜋
# 𝜎
# 2
# 𝑒
# −
# (
# 𝑥
# −
# 𝜇
# )
# 2
# 2
# 𝜎
# 2
# f(x)=
# 2πσ
# 2
#
# ​
#
# 1
# ​
#  e
# −
# 2σ
# 2
#
# (x−μ)
# 2
#
# ​
#
#
# Where:
#
# 𝑥
# x = Random variable
#
# 𝜇
# μ = Mean
#
# 𝜎
# σ = Standard Deviation
#
#  Empirical Rule (68-95-99.7 Rule)
#
# The Empirical Rule provides a quick estimation of how data is distributed within a normal distribution. It states that:
#
# 68% of data falls within one standard deviation of the mean (
# 𝜇
# ±
# 𝜎
# μ±σ).
#
# 95% of data falls within two standard deviations of the mean (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ).
#
# 99.7% of data falls within three standard deviations of the mean (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ).
#
# This rule helps us understand the spread and concentration of data in a normal distribution.

# %%
## QUES 10) Provide a real-life example of a Poisson process and calculate the probability for a specific event

# %% [markdown]
# Real-Life Example of a Poisson Process
# The Poisson process is commonly used to model random events that occur independently over a fixed interval of time or space. A classic real-life example is counting the number of customers arriving at a store per hour.
#
#  Example Scenario
#
# Suppose a fast-food restaurant receives an average of 6 customers per minute during peak hours. The arrivals are assumed to be independent of each other and follow a Poisson distribution.
#
# Problem Statement
# Calculate the probability that exactly 8 customers will arrive within a given minute.
#
#  Poisson Distribution Formula
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Where:
#
# 𝑋
# X = Number of occurrences (customers arriving)
#
# 𝑘
# k = Number of occurrences we want to find the probability of (8 customers)
#
# 𝜆
# λ = Average rate of occurrences per interval (6 customers per minute)
#
# 𝑒
# e = Euler's number (approximately 2.71828)
#
# Given:
#
# 𝜆
# =
# 6
# λ=6 (Average number of customers per minute)
#
# 𝑘
# =
# 8
# k=8 (We want to find the probability of exactly 8 customers arriving)
#
# 𝑃
# (
# 𝑋
# =
# 8
# )
# =
# 𝑒
# −
# 6
# ×
# 6
# 8
# 8
# !
# P(X=8)=
# 8!
# e
# −6
#  ×6
# 8
#
# ​
#
# So, the probability of exactly 8 customers arriving in one minute is approximately 0.1033 (or 10.33%).
#
# Interpretation
# Since the probability is about 10.33%, it’s not extremely unlikely for exactly 8 customers to arrive in a single minute during peak hours.
#
# If you wanted to find the probability of 8 or fewer customers, you would sum the probabilities from 0 to 8 (Cumulative Probability).

# %%
## QUES 11)  Explain what a random variable is and differentiate between discrete and continuous random variables.

# %% [markdown]
# Random Variable
# A random variable is a variable that takes on numerical values determined by the outcome of a random experiment. It maps outcomes of a random process to numerical values.
#
# Example: Rolling a die. Possible outcomes are
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# 1,2,3,4,5,6.
#
# Random Variable
# 𝑋
# X: The number showing on the die.
#
# 𝑋
# X can take values
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# 1,2,3,4,5,6.
#
#  Types of Random Variables
#
# 1. Discrete Random Variable
# A discrete random variable is one that takes on a countable number of distinct values. The values are often whole numbers.
#
# Characteristics:
# Countable (finite or infinite but countable).
#
# Gaps exist between possible values.
#
# Usually represents counts or categorical outcomes.
#
# Examples:
# Number of customers entering a store in an hour (0, 1, 2, 3, ...).
#
# Rolling a die (1, 2, 3, 4, 5, 6).
#
# Number of defective items in a batch (0, 1, 2, ...).
#
# 2. Continuous Random Variable
# A continuous random variable is one that takes on infinitely many values within a given range. These values are often represented by intervals on the real number line.
#
# Characteristics:
#
# Uncountable (infinite possibilities within a range).
#
# No gaps between possible values.
#
# Usually represents measurements.
#
# Examples:
# Height of students in a class (e.g., 160.5 cm, 160.55 cm, etc.).
#
# Time taken to complete a task (e.g., 2.34 minutes, 2.345 minutes, etc.).
#
# Temperature (e.g., 22.1°C, 22.15°C, etc.).

# %%
## QUES 12) Provide an example dataset, calculate both covariance and correlation, and interpret the results.

# %% [markdown]
# Example Dataset:
# Let's consider a small dataset of two variables:
#
# X (Study Hours)	Y (Test Scores)
# 2	50
# 3	60
# 5	65
# 4	70
# 6	80
# 8	85
# 𝑋
# X: Study Hours
#
# 𝑌
# Y: Test Scores
#
#  Calculating Mean of Each Variable:
#
# Mean of
# 𝑋
# =
# 2
# +
# 3
# +
# 5
# +
# 4
# +
# 6
# +
# 8
# 6
# =
# 28
# 6
# =
# 4.67
# Mean of X=
# 6
# 2+3+5+4+6+8
# ​
#  =
# 6
# 28
# ​
#  =4.67
# Mean of
# 𝑌
# =
# 50
# +
# 60
# +
# 65
# +
# 70
# +
# 80
# +
# 85
# 6
# =
# 410
# 6
# =
# 68.33
# Mean of Y=
# 6
# 50+60+65+70+80+85
# ​
#  =
# 6
# 410
# ​
#  =68.33
# Calculating Covariance:
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 𝑛
# −
# 1
# Cov(X,Y)=
# n−1
# ∑
# i=1
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# ​
#
# =
# (
# 2
# −
# 4.67
# )
# (
# 50
# −
# 68.33
# )
# +
# (
# 3
# −
# 4.67
# )
# (
# 60
# −
# 68.33
# )
# +
# (
# 5
# −
# 4.67
# )
# (
# 65
# −
# 68.33
# )
# +
# (
# 4
# −
# 4.67
# )
# (
# 70
# −
# 68.33
# )
# +
# (
# 6
# −
# 4.67
# )
# (
# 80
# −
# 68.33
# )
# +
# (
# 8
# −
# 4.67
# )
# (
# 85
# −
# 68.33
# )
# 6
# −
# 1
# =
# 6−1
# (2−4.67)(50−68.33)+(3−4.67)(60−68.33)+(5−4.67)(65−68.33)+(4−4.67)(70−68.33)+(6−4.67)(80−68.33)+(8−4.67)(85−68.33)
# ​
#
# =
# (
# −
# 2.67
# )
# (
# −
# 18.33
# )
# +
# (
# −
# 1.67
# )
# (
# −
# 8.33
# )
# +
# (
# 0.33
# )
# (
# −
# 3.33
# )
# +
# (
# −
# 0.67
# )
# (
# 1.67
# )
# +
# (
# 1.33
# )
# (
# 11.67
# )
# +
# (
# 3.33
# )
# (
# 16.67
# )
# 5
# =
# 5
# (−2.67)(−18.33)+(−1.67)(−8.33)+(0.33)(−3.33)+(−0.67)(1.67)+(1.33)(11.67)+(3.33)(16.67)
# ​
#
# =
# 48.92
# +
# 13.91
# −
# 1.10
# −
# 1.12
# +
# 15.52
# +
# 55.52
# 5
# =
# 5
# 48.92+13.91−1.10−1.12+15.52+55.52
# ​
#
# =
# 131.65
# 5
# =
# 5
# 131.65
# ​
#
# =
# 18.00
# =18.00
# Covariance = 18.00
#
# Calculating Correlation:
#
# Correlation
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝑆
# 𝑋
# 𝑆
# 𝑌
# Correlation=
# S
# X
# ​
#  S
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Where:
#
# 𝑆
# 𝑋
# S
# X
# ​
#   = Standard deviation of
# 𝑋
# X
#
# 𝑆
# 𝑌
# S
# Y
# ​
#   = Standard deviation of
# 𝑌
# Y
#
# Calculating Standard Deviation
# 𝑆
# 𝑋
# =
# (
# 2
# −
# 4.67
# )
# 2
# +
# (
# 3
# −
# 4.67
# )
# 2
# +
# (
# 5
# −
# 4.67
# )
# 2
# +
# (
# 4
# −
# 4.67
# )
# 2
# +
# (
# 6
# −
# 4.67
# )
# 2
# +
# (
# 8
# −
# 4.67
# )
# 2
# 5
# S
# X
# ​
#  =
# 5
# (2−4.67)
# 2
#  +(3−4.67)
# 2
#  +(5−4.67)
# 2
#  +(4−4.67)
# 2
#  +(6−4.67)
# 2
#  +(8−4.67)
# 2
#
# ​
#
# ​
#
# =
# 7.11
# +
# 2.79
# +
# 0.11
# +
# 0.45
# +
# 1.76
# +
# 11.11
# 5
# =
# 5
# 7.11+2.79+0.11+0.45+1.76+11.11
# ​
#
# ​
#
# =
# 23.33
# 5
# =
# 4.67
# =
# 2.16
# =
# 5
# 23.33
# ​
#
# ​
#  =
# 4.67
# ​
#  =2.16
# 𝑆
# 𝑌
# =
# (
# 50
# −
# 68.33
# )
# 2
# +
# (
# 60
# −
# 68.33
# )
# 2
# +
# (
# 65
# −
# 68.33
# )
# 2
# +
# (
# 70
# −
# 68.33
# )
# 2
# +
# (
# 80
# −
# 68.33
# )
# 2
# +
# (
# 85
# −
# 68.33
# )
# 2
# 5
# S
# Y
# ​
#  =
# 5
# (50−68.33)
# 2
#  +(60−68.33)
# 2
#  +(65−68.33)
# 2
#  +(70−68.33)
# 2
#  +(80−68.33)
# 2
#  +(85−68.33)
# 2
#
# ​
#
# ​
#
# =
# 336.11
# +
# 69.44
# +
# 11.11
# +
# 2.78
# +
# 136.11
# +
# 278.44
# 5
# =
# 5
# 336.11+69.44+11.11+2.78+136.11+278.44
# ​
#
# ​
#
# =
# 833.99
# 5
# =
# 166.8
# =
# 12.91
# =
# 5
# 833.99
# ​
#
# ​
#  =
# 166.8
# ​
#  =12.91
# Calculating Correlation
# Correlation
# =
# 18.00
# 2.16
# ×
# 12.91
# Correlation=
# 2.16×12.91
# 18.00
# ​
#
# =
# 18.00
# 27.89
# =
# 27.89
# 18.00
# ​
#
# =
# 0.98
# =0.98
# Correlation = 0.98
#
#  Interpretation
# Covariance
# The covariance between
# 𝑋
# X and
# 𝑌
# Y is 18.00.
#
# A positive value indicates a positive relationship: as study hours increase, test scores also tend to increase.
#
# However, the magnitude of covariance is not standardized, making it difficult to interpret the strength of the relationship.
#
# Correlation
# The correlation coefficient is 0.98.
#
# It is very close to +1, indicating a strong positive linear relationship between
# 𝑋
# X (Study Hours) and
# 𝑌
# Y (Test Scores).
#
# The closer the value is to +1 or -1, the stronger the linear relationship. A value of 0 indicates no linear relationship.
